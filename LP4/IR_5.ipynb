# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

titles = []
news = []
categories = []

url = f"https://www.bbc.com/bengali/topics/c907347rezkt?page=2"

# Send an HTTP GET request and parse the content with BeautifulSoup
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all the <li> elements with class 'bbc-t44f9r'
li_elements = soup.find_all('li', class_='bbc-t44f9r')

# Loop through each 'li' element
for li in li_elements:
    try:
        # Extract the title from the <a> tag within the <li>
        title = li.find('a').text.strip()
        #Define the category
        category = 'World'
        # Extract the link to the news article
        link = li.find('a')['href']

        # Send an HTTP GET request to the article link and parse its content
        article_response = requests.get(link)
        article_soup = BeautifulSoup(article_response.text, 'html.parser')

        # Find and extract the news content from the <p> tag with class 'bbc-12k5sdr e17g058b0'
        post_content_div = article_soup.find('div', class_='bbc-1cvxiy9')
        if post_content_div:
            news_content = " ".join([p.text.strip() for p in post_content_div.find_all('p')])
        else:
            news_content = " "

        titles.append(title)
        categories.append(category)
        news.append(news_content)

    except Exception as e:
        print(f"Error: {e}")
        pass

# Create a DataFrame
data = {'Title': titles, 'Category': category, 'News': news}
df = pd.DataFrame(data)

df.head()
# Out:
#                                                Title Category  \
# 0  যেসব কারণে বাংলাদেশের জন্য এবারের জাতিসংঘ সম্ম...    World
# 1  শ্রীলঙ্কায় গণ-বিক্ষোভ পরবর্তী প্রেসিডেন্ট নির্...    World
# 2  নাফ নদী হয়ে নতুন করে যেভাবে বাংলাদেশে ঢুকছে রে...    World
# 3  ইসরায়েলি গোয়েন্দা সংস্থা মোসাদের যত সফল ও ব্যর...    World
# 4    লেবাননের বৈরুতে ইসরায়েলি বিমান হামলায় নয়জন নিহত    World
#
#                                                 News
# 0  ছবির উৎস, Getty Images বাংলাদেশের প্রধান উপদেষ...
# 1  ছবির উৎস, Getty Images শ্রীলঙ্কায় গণ-বিক্ষোভের...
# 2  বাংলাদেশে সম্প্রতি নতুন করে রোহিঙ্গা অনুপ্রবেশ...
# 3  ছবির উৎস, Getty Images পেজার-সহ (যোগাযোগের তার...
# 4  ছবির উৎস, ANWAR AMRO/AFP via Getty Images লেবা...
